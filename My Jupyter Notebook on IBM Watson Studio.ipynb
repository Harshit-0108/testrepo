# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# <b> HARSHIT AGARWAL </b>
# <br> Chartered Accountant

# %% [markdown]
# _I am interested in Data Science because this skill would help me in my career growth and open doors to new opportunities_

# %% [markdown]
# ### In Cell 5, I would perform a simple math of 3*5

# %%
3*5
# Out:
# 15

# %% [markdown]
# - This is a bullet
# 1. This is a Numbered List 1
# 2. This is a Numbered List 2
#
# _[IBM Webiste](https://www.ibm.com/in-en)_
#
# <br><br> ~This is a Strikethrough~
